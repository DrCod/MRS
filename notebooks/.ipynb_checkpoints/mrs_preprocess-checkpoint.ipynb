# %%
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
import mkl_fft as fft

# %%
#load the ACE data points: 2048 points
mr_signals = pd.read_csv("../Ace.txt")

# %%
#displaying the head of the signals
mr_signals.head(20)
# Out:
#                            jMRUI Data Textfile
# 0                            Filename: Ace.txt
# 1                  PointsInDataset: 2048
# 2                   DatasetsInFile: 1
# 3                 SamplingInterval: 2.5E-1
# 4                   ZeroOrderPhase: 0E0
# 5                        BeginTime: 0E0
# 6             TransmitterFrequency: 1.2322E8
# 7                    MagneticField: 2.9E0
# 8                    TypeOfNucleus: 0E0
# 9                           NameOfPatient: Ace
# 10                          DateOfExperiment:
# 11                              Spectrometer:
# 12                         AdditionalInfo: Ace
# 13                       SignalNames: Ace.txt;
# 14                              Signal and FFT
# 15  sig(real)\tsig(imag)\tfft(real)\tfft(imag)
# 16                   Signal 1 out of 1 in file
# 17                       3.1000000\t-0.0000000
# 18                       2.6438500\t-1.5967800
# 19                       1.4305400\t-2.7108100
